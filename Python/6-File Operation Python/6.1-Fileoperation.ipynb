# %% [markdown]
# #### File Operation - Read and Write Files
#
#
# - File handling is an important part of programming.
#
# - Python has built‑in tools for reading and writing files.
#
# - You can work with both text files and binary files.
#
# - File handling includes operations like opening, reading, writing, and closing files.
#
# - This lesson focuses on the basics of handling text and binary files.

# %% [markdown]
# ### Text

# %% [markdown]
# ##### Read the Whole File

# %%
## Reading a whole file

with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello Mf?
# I am good
# I am the King
# Nice to meet you MF

# %% [markdown]
# #### Read Line by Line

# %%
## Read a file line by line

with open('example.txt', 'r') as file:
    for line in file:
        print(line.strip())  # .strip() removes the newline character
# Out:
# Hello Mf?
# I am good
# I am the King
# Nice to meet you MF

# %% [markdown]
# #### Writing a file (Overwriting)

# %%
## Writing a file(Overwriting)

with open('example.txt', 'w') as file:
    file.write('Hello World!\n')
    file.write('This is a new line\n')

# %%
## Writing a file without overwriting

with open('example.txt', 'a') as file:
    file.write('Append operation taking place')

# %%
## Writing List of lines to a file

lines = ['First Line\n', 'Second Line\n', 'Third Line\n']

with open('example.txt', 'a') as file:
    file.writelines(lines)

# %% [markdown]
# ### Binary Files

# %% [markdown]
# #### Reading Binary Files

# %%
## Binary Files

## Write Binary File
data = b'x00\x01\x02\x03\x04'
with open('example.bin', 'wb') as file:
    file.write(data)

# %%
## Reading
with open('example.bin', 'rb') as file:
    content = file.read()
    print(content)
# Out:
# b'x00\x01\x02\x03\x04'

# %%
### Read the content from source text file to a destination text file
# Copying a text file

with open('example.txt', 'r') as source_file:
    content = source_file.read()

with open('destination.txt', 'w') as destination_file:
    destination_file.write(content)

# %% [markdown]
# #### Counting Lines, Words and Characters in a Text File

# %%
## Read a text file and count the number of lines, words and characters

def count_text_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
        return line_count, word_count, char_count

file_path = 'example.txt'
lines, words, characters = count_text_file(file_path)
print(f"Lines: {lines}, Words: {words}, Characters: {characters}")
# Out:
# Lines: 6, Words: 23, Characters: 154

# %% [markdown]
# #### Writing and then Reading a File

# %% [markdown]
#  - The w+ mode in Python is used to open a file for both reading and writing
#  - If the file does not exist, it will be created.
#  - If the files exists its content will be truncated (i.e the file is overwritten)

# %%
## Writing and Reading a file

with open('example.txt', 'w+') as file:
    file.write("Hello MFs\n")
    file.write("This is the beginning of it all \n")

    ## Move the cursor to the beginning
    file.seek(0)

    ## Read the content of the file
    content = file.read()
    print(content)
# Out:
# Hello MFs
# This is the beginning of it all
