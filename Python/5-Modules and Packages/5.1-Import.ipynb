# %% [markdown]
# ### Import Modules in Python: Modules and Packages
#
#
# - Organise and reuse Code

# %% [markdown]
# #### Importing Modules and Packages

# %%
## Importing Packages

import math

## Squareroot of a number
math.sqrt(16)
# Out:
# 4.0

# %%
## Use squareroot and pi

from math import sqrt,pi
print(sqrt, 81)
print(sqrt, 25)

print(pi)
# Out:
# <built-in function sqrt> 81
# <built-in function sqrt> 25
# 3.141592653589793

# %%
## Numpy
## Used for creating arrays


import numpy as np

# %%
## Numpy
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
## Every module in math
from math import *

sqrt(25)
print(pi)
# Out:
# 3.141592653589793

# %%
import pandas as pd

# %%
from package.maths import addition
addition(2, 3)
# Out:
# 5

# %%
##
from package import maths
maths.addition(2,4)
# Out:
# 6

# %%
# from package.maths import *
# maths.subtraction(9, 7)
