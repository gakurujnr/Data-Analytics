# %% [markdown]
# ### Data Visualization With Seaborn
#
# - Seaborn is a Python visualization library built on top of Matplotlib.
#
# - Provides a high‑level interface for creating attractive statistical graphics.
#
# - Makes it easy to build complex visualizations with very little code.
#
# - Commonly used for statistical data analysis and visualization.

# %%
## Installing
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
## Basic Plotting with Searborn
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Scatter Plor
import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Scatter Plot of Total Bill Vs Tip")
plt.show()

# %%
## Line Plot
sns.lineplot(x='size', y='total_bill', data=tips)
plt.title("Line Plot of Total Bill and SIze")
plt.show()

# %%
## Categorical Plot
## Bar Plot
sns.barplot(x='day', y='total_bill', data=tips)
plt.title("Bar Plot of Total Plot by Bill")
plt.show()

# %%
## Box Plot -  Amazing ways of seeing Outliers and Anomalies
sns.boxplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
## Distribution of the Data
# Violin Plot - Gives an idea of how the distribution of the data is with respect to the total bill
sns.violinplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
## Histograms
sns.histplot(tips['total_bill'], bins=10, kde=True)
# kde=True - shows how your data is distributed
plt.show()

# %%
## KDE Plot
sns.kdeplot(tips['total_bill'], fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## Pairplot - see relationship between all the variable to the different variables
sns.pairplot(tips)

# %%
## Corelation with the help of Heatmap
# Heatmap

corr = tips[['total_bill', 'tip', 'size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# Heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# All has a positive correlation

# %%
## Customization

import pandas as pd

sales = pd.read_csv('sales_data.csv')
sales.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# ...

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sale_Date             1000 non-null   str
#  2   Sales_Rep             1000 non-null   str
#  3   Region                1000 non-null   str
#  4   Sales_Amount          1000 non-null   float64
#  5   Quantity_Sold         1000 non-null   int64
#  6   Product_Category      1000 non-null   str
#  7   Unit_Cost             1000 non-null   float64
#  8   Unit_Price            1000 non-null   float64
#  9   Customer_Type         1000 non-null   str
#  10  Discount              1000 non-null   float64
#  11  Payment_Method        1000 non-null   str
#  12  Sales_Channel         1000 non-null   str
#  13  Region_and_Sales_Rep  1000 non-null   str
# dtypes: float64(4), int64(2), str(8)
# memory usage: 109.5 KB

# %%
## Plot Sales Amount by Product Category
plt.figure(figsize=(10,6))
sns.barplot(x='Product_Category', y='Sales_Amount', data=sales, estimator=sum)
plt.title("Plot Sales Amount by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Sales Amount")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Region', y='Sales_Amount', data=sales, estimator=sum)
plt.title("Plot Sales Amount by Product Category")
plt.xlabel("Region")
plt.ylabel("Sales Amount")
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
