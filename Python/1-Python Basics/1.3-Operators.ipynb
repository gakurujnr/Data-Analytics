# %% [markdown]
# ### Outline
#
#
# 1. Introduction to Operators
# 2. Arithmentic Operators
#     - Addition
#     - Subtraction
#     - Multiplication
#     - Division
#     - Floor Division
#     - Modulus
#     - Exponentiation
# 3. Comparison Operators
#     - Equal to
#     - Not Equal to
#     - Greater than
#     - Less than
#     - Greater than or equal to
#     - Less than or equal to
# 4. Logical Operators
#     - AND
#     - OR
#     - NOT
# 5. Practical examples and Common Errors

# %% [markdown]
# #### Comparison Operators

# %%
## Arithmetic Operation

a =10
b=5

add_result = a+b    # Addition
sub_result = a-b    # Subtraction
mul_result = a*b    # Multiplication
div_result = a/b    # Division
floor_div_result = a//b    # Floor Division
modulus_result = a%b    # Modulus

exponent_result = a**b    # Exponentiation

print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(modulus_result)
print(exponent_result)
print(floor_div_result)
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 100000
# 2

# %%
# 
10/5

# %%
# Comparison Operators
# ==

a = 10
b = 10

result = a==b
print(result)
# Out:
# True

# %%
str1="Peter"
str2="Peter"

str1==str2
# Out:
# True

# %%
# Not Equal to !=
str1!=str2
# Out:
# False

# %%
str3="Peter"
str4="peter"

str3!=str4
# Out:
# True

# %%
# Greater than >
num1=45
num2=55

num1>num2
# Out:
# False

# %%
# Less than <
num1<num2
# Out:
# True

# %%
# Greater than or Equal to >=
number1=45
number2=45

number1>=number2

# Less than or Equal to <=
number1<=number2
# Out:
# True

# %% [markdown]
# #### Logical Operators

# %%
## AND, NOT, OR Operators
# AND Operator
X=True
Y = True

result = X and Y
print(result)
# Out:
# True

# %%
# AND
X = False
Y = True

result= X and Y
print(result)
# Out:
# False

# %%
## OR Operator
# It returns True if any of the operands is True. If both are False, it returns False.

X=False
Y=False

result = X or Y
print(result)
# Out:
# False

# %%
X=True
Y=False

result = X or Y
print(result)
# Out:
# True

# %%
# NOT Operator
## NOT operator is used to reverse the logical state of its operand. If a condition is True, then NOT operator will make it False.

X = True
not X
# Out:
# False

# %%
X=False
not X
# Out:
# True

# %%
# Simple Calculator

# Creating a Simple Calculator

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))    

addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2

## Display the Result
print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", floor_division)
print("Modulus:", modulus)
print("Exponentiation:", exponentiation)

## Numbers num1 = 12 and num2 = 5
# Out:
# Addition: 17.0
# Subtraction: 7.0
# Multiplication: 60.0
# Division: 2.4
# Floor Division: 2.0
# Modulus: 2.0
# Exponentiation: 248832.0
