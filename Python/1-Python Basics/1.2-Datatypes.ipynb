# %% [markdown]
# ### DataTypes
#
#
# 1. Definition
#
#    - Data types are a classification of data which tell the compiler or interpreter how the program intends to use the data
#    - They determine the type of operations that can be performed on the data, the values that the data can take, and the amount of memory needed to store the data.
#
# 2. Importance of Data Types in Programming
#
#   - Data types ensures that the data is stored in an efficient way
#   - They help in performing correct operations on data.
#   - Proper use of data types can prevent errors and bugs in the program.
#
#
# ### Outline
#
# 1. Introduction to Data Types
# 2. Importance of Data Types in Programming
# 3. Basic Data Types
#     - Integers
#     - Floating-point numbers
#     - Strings
#     - Booleans
# 4. Advanced Data Types
#     - Lists
#     - Tuples
#     - Sets
#     - Dictionaries
# 5. Type Conversion
# 6. Practical Example

# %%
## Integers Example
age = 30
type(age)
# Out:
# int

# %%
## Floating Point datatype
height = 5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
# String Data type example
name = "Peter"
print(name)
print(type(name))
# Out:
# Peter
# <class 'str'>

# %%
# Boolean Datatypes
is_true = True
type(is_true)
# Out:
# bool

# %%
is_true = bool()
is_true
# Out:
# False

# %%
is_True = True
type(is_True)
# Out:
# bool

# %%
a = 10
b=10

type(a==b)
# Out:
# bool

# %%
# Common errors on Data Types

result="Hello" + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Common errors on Data Types
#       2
# ----> 3 result="Hello" + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Fixing the error
result="Hello" + str(10)
print(result)
# Out:
# Hello10

# %%
str = "Hello"

str.
